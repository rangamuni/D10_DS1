# %%
import numpy as np
'9''-> Methods'
arr = np.arange(10,1,-1)
arr = np.ones((3,5),dtype=int)
arr = np.zeros((3,3),dtype=int)
arr = np.full((3,),7)
arr = np.eye(3,5,dtype=int)
arr = np.linspace(1,10,7)
arr.reshape(7,1)
arr.flatten()
arr.ravel()
''
r = np.array([[1,2],
            [3,4]])
f=r.ravel()
f1=r.flatten()
f[0]=101
f1[0]=102
r
r
# Out:
# array([[101,   2],
#        [  3,   4]])

# %%
'operations and booleans'
arr1 = np.array([1,2,3,4])
arr2 = np.array([5,6,7,8])
arr1+3
np.add(arr1,arr2)
np.subtract(arr1,arr2)
np.multiply(arr1,arr2)
np.divide(arr1,arr2)
np.floor_divide(arr1,arr2)
np.mod(arr1,arr2)
np.power(arr1,arr2)
arr1 < 3
arr1 > 3
arr1 <= 3
arr1 >= 3
arr2 == arr1
np.less(arr1,arr2) #'greater,equal,not_equal'
arr1,arr2
arr1[-1] # it will accept negative index
np.sort(arr1)[::-1] # sorting purpose
arr1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 'operations and booleans'
# ----> 2 arr1 = np.array([1,2,3,4])
#       3 arr2 = np.array([5,6,7,8])
#       4 arr1+3
#       5 np.add(arr1,arr2)
#
# NameError: name 'np' is not defined

# %%
'slicing'
# s = np.array([[1,2,3,0],
#             [4,5,6,1],
#             [7,8,9,2]])
# s[0:3:2,1:3]
# s.T  # "row <-> columns"
import numpy as np
arr1 = np.array([1,2,3,4])
arr1
np.max(arr1)
np.min(arr1)
np.argmax(arr1)
np.argmin(arr1)
# Out:
# np.int64(0)
