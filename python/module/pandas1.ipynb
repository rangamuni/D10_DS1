# %%
import pandas as pd
df = pd.DataFrame({
    'name':['ram','sam','tom'],
    'Age':[20,29,19]
})
df
# Out:
#   name  Age
# 0  ram   20
# 1  sam   29
# 2  tom   19

# %%
df = pd.read_csv(r"c:\Users\USER\OneDrive\Desktop\resltfile.csv")
# df = pd.read_excel(r"c:\Users\USER\Downloads\D10_RANGAMUNI_EXCEL_DEMO_PROJECT.xlsx")
df
# Out:
#     ï»¿video_id channel_name                 title   category  views   likes  \
# 0          9001    TechWorld  Roadmap to Learn SQL  Education  50000  2500.0
# 1          9002   CookWithMe  Tasty Biryani Recipe       Food  30000  1800.0
# 2          9003   GamingZone          Top 10 Games     Gaming    abc  2000.0
# 3          9004          NaN                   NaN      Music  20000     NaN
# 4          9005      FitLife          Workout Tips    Fitness  40000  2200.0
# ..          ...          ...                   ...        ...    ...     ...
# 58         9066   CookWithMe           Quick Meals       Food  30000  1800.0
# 59         9067   GamingZone          Apex Legends     Gaming  54000  2700.0
# 60         9068      FitLife          Home Workout    Fitness  26000  1400.0
# 61         9069    TravelNow          Hill Station     Travel  35000  1900.0
# 62         9070     MusicHub           Indie Songs      Music  62000  3100.0
#
# ...

# %%
# df.columns
df.__rpow__

# df.describe()
# Out:
# <bound method OpsMixin.__rpow__ of     ï»¿video_id channel_name                 title   category  views   likes  \
# 0          9001    TechWorld  Roadmap to Learn SQL  Education  50000  2500.0
# 1          9002   CookWithMe  Tasty Biryani Recipe       Food  30000  1800.0
# 2          9003   GamingZone          Top 10 Games     Gaming    abc  2000.0
# 3          9004          NaN                   NaN      Music  20000     NaN
# 4          9005      FitLife          Workout Tips    Fitness  40000  2200.0
# ..          ...          ...                   ...        ...    ...     ...
# 58         9066   CookWithMe           Quick Meals       Food  30000  1800.0
# 59         9067   GamingZone          Apex Legends     Gaming  54000  2700.0
# 60         9068      FitLife          Home Workout    Fitness  26000  1400.0
# 61         9069    TravelNow          Hill Station     Travel  35000  1900.0
# 62         9070     MusicHub           Indie Songs      Music  62000  3100.0
#
# ...

# %%
df = pd.read_csv(r"c:\Users\USER\OneDrive\Desktop\resltfile.csv")
# df = pd.read_excel(r"c:\Users\USER\Downloads\D10_RANGAMUNI_EXCEL_DEMO_PROJECT.xlsx")
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ï»¿video_id   63 non-null     int64
#  1   channel_name  59 non-null     str
#  2   title         57 non-null     str
#  3   category      60 non-null     str
#  4   views         57 non-null     str
#  5   likes         57 non-null     float64
#  6   dislikes      58 non-null     float64
#  7   comments      58 non-null     float64
#  8   publish_date  57 non-null     str
#  9   city          62 non-null     str
#  10  status        62 non-null     str
# dtypes: float64(3), int64(1), str(7)
# memory usage: 5.5 KB
#        ï»¿video_id       likes    dislikes    comments
# count    63.000000    57.00000   58.000000   58.000000
# mean   9034.777778  2008.77193   86.551724  229.137931
# std      20.063966   697.51618   38.505034   90.984566
# min    9001.000000     0.00000    0.000000    0.000000
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined
